# %%
import numpy as np

# %%
import numpy as up
a = [1,2,3,4]
b = np.array(a)
print(b)
display(b)
print(type(b))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-2e1d9b822970> in <module>()
#       1 import numpy as up
#       2 a = [1,2,3,4]
# ----> 3 b = np.array(a)
#       4 print(b)
#       5 display(b)
#
# NameError: name 'np' is not defined

# %%
import numpy as np
a = [1,2,3,4]
b = np.array(a)
print(b)
display(b)
print(type(b))
# Out:
# [1 2 3 4]
# array([1, 2, 3, 4])
# <class 'numpy.ndarray'>

# %%
import numpy as np
a = [1,2,3,4]
b = np.array(a)
print(b)
display(b) #display 返回带类型，jupter自带
print(type(b))
# Out:
# [1 2 3 4]
# array([1, 2, 3, 4])
# <class 'numpy.ndarray'>

# %%
c = [[1,2],[3,4]] #二维列表
d = np.array(c)#二维numpy数组
display(d)
display(d.shape)
# Out:
# array([[1, 2],
#        [3, 4]])
# (2, 2)

# %%
display(b.ndim)#几维
# Out:
# 1

# %%
display(d.ndim)
# Out:
# 2

# %%
display(b.shape)#形状
# Out:
# (4,)

# %%
display(b.size)#长度
# Out:
# 4

# %%
zjj = [1,2,3,4]
lyj = [1.1,2.2,3.3]
zjj_array = np.array(zjj)
lyj_array = np.array(lyj)
display(zjj_array.dtype,lyj_array.dtype)
# Out:
# dtype('int32')
# dtype('float64')

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
girl = plt.imread('C:\\Users\\Administrator\\Desktop\\python1\\asdf.jpg')
display(girl)
# Out:
# array([[[254, 245, 212],
#         [250, 241, 208],
#         [253, 240, 206],
#         ...,
#         [246, 228, 192],
#         [249, 226, 192],
#         [255, 232, 198]],
#
#        [[251, 247, 212],
#         [250, 244, 210],
#         [251, 241, 206],
#         ...,
#         [249, 233, 197],
#         [248, 228, 193],
#         [250, 227, 193]],
#
#        [[250, 247, 212],
#         [247, 243, 208],
#         [247, 241, 205],
#         ...,
#         [251, 242, 203],
#         [249, 235, 198],
#         [246, 230, 194]],
#
#        ...,
#
#        [[255, 253, 255],
#         [255, 251, 238],
#         [254, 241, 207],
#         ...,
#         [253, 236, 193],
#         [252, 235, 192],
#         [251, 234, 191]],
#
#        [[251, 251, 253],
#         [253, 250, 235],
#         [249, 241, 205],
#         ...,
#         [254, 237, 194],
#         [253, 236, 193],
#         [252, 235, 192]],
#
#        [[247, 252, 255],
#         [248, 251, 234],
#         [247, 243, 208],
# ...

# %%
plt.imshow(girl)

# %%
girl_change = girl.copy()

# %%
girl_change.shape
# Out:
# (607, 900, 3)

# %%
for i in range(800):
    for j in range(800):
        for k in range(3):
            if girl_change[i][j][k] ==160:
                girl_change[i][j][k] =0
            if girl_change[i][j][k] ==50:
                girl_change[i][j][k] =7
            if girl_change[i][j][k] ==111:
                girl_change[i][j][k] =68
            if girl_change[i][j][k] ==225:
                girl_change[i][j][k] =8
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-19-7708e5285fd7> in <module>()
#       2     for j in range(800):
#       3         for k in range(3):
# ----> 4             if girl_change[i][j][k] ==160:
#       5                 girl_change[i][j][k] =0
#       6             if girl_change[i][j][k] ==50:
#
# IndexError: index 607 is out of bounds for axis 0 with size 607

# %%
girl_change

# %%
plt.imshow(girl_change)
